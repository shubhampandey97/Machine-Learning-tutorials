# %%
from sklearn.datasets import make_regression

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
# Gradient descent for linear regression
b = -150
m = 150
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(X.shape[0]):
        slope_b = slope_b - 2 * (y[j] - (m * X[j]) - b)
        slope_m = slope_m - 2 * (y[j] - (m * X[j]) - b) * X[j]
        cost = cost + (y[j] - m * X[j] - b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
from IPython.display import IFrame

IFrame(src="http://127.0.0.1:5500/Gradient%20Descent/cost_function2.html", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="http://127.0.0.1:5500/Gradient%20Descent/cost_function2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(M, B, Cost, cmap='viridis', alpha=0.7)
ax.set_xlabel('Slope (m)')
ax.set_ylabel('Intercept (b)')
ax.set_zlabel('Cost')
ax.set_title('Cost Function Surface with Gradient Descent Path')

# Plot the gradient descent path
ax.plot(all_m_flat, all_b_flat, all_cost_flat, color='r', marker='o', markersize=3, label='Gradient Descent Path')
ax.legend()
plt.show()
