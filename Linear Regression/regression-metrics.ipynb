# %% [markdown]
# #### Importing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# #### Loading dataset

# %%
import sys
from pathlib import Path

# Get current notebook path
current_path = Path().resolve()

# Go up until you find 'src'
for parent in current_path.parents:
    if (parent / "src").exists():
        sys.path.append(str(parent / "src"))
        print("Added to path:", parent / "src")
        break
# Out:
# Added to path: D:\Data Science\Machine Learning\src

# %%
from utils.paths import RAW_DATA_DIR

# %%
# import sys
# print(sys.path[-1])

# %%
import pandas as pd

df = pd.read_csv(RAW_DATA_DIR / "placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# #### Basic Data Inspection

# %%
print(df.head())
print(df.shape)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# (200, 2)

# %% [markdown]
# #### Data Visualization

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# #### Feature & Target Split

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %% [markdown]
# #### Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# #### Model Training (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Regression Line Visualization

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# $$
# y = mx + c
# $$

# %% [markdown]
# #### Predictions & Evaluation Metrics

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))         # MAE (Mean Absolute Error)
print("MSE",mean_squared_error(y_test,y_pred))          # MSE (Mean Squared Error)
# Out:
# MAE 0.2884710931878175
# MSE 0.12129235313495527

# %% [markdown]
# $$
# MAE = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|
# $$
#
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))        # RMSE(Square root of MSE (more interpretable))
# Out:
# RMSE 0.34827051717731616

# %% [markdown]
# $$
# RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2}
# $$
#
# $$
# RMSE = \sqrt{MSE}
# $$

# %%
print("R2",r2_score(y_test,y_pred))        # R² Score
# Out:
# R2 0.780730147510384

# %% [markdown]
# $$
# R^2 = 1 - \frac{\sum (y_i - \hat{y}_i)^2}{\sum (y_i - \bar{y})^2}
# $$
#
# $$
# e_i = y_i - \hat{y}_i
# $$
#
#
# $$
# \bar{y} = \frac{1}{n} \sum_{i=1}^{n} y_i
# $$

# %%
r2 = r2_score(y_test,y_pred)

# print(X_test.shape)
Adjusted_r2_score = 1 - ((1-r2)*(40-1)/(40-1-1))        # Adjusted R2 score
print("Adjusted R2 score",Adjusted_r2_score)
# Out:
# Adjusted R2 score 0.7749598882343415

# %% [markdown]
# $$
# Adjusted\ R^2 = 1 - \frac{(1 - R^2)(n - 1)}{(n - k - 1)}
# $$

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.439798     3.26
# 1  5.12        0.230093     1.98
# 2  7.82        0.444112     3.25
# 3  7.42        0.274052     3.67
# 4  6.94        0.996945     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7796427157727736

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7677315112199505

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 113  6.94  1.47     2.37
# 97   5.98  2.04     2.84
# 173  6.75  3.56     2.56
# 120  5.23  1.93     1.73
# 162  5.53  3.05     2.55

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# -66

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.8004221523102335

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7896341605432191
